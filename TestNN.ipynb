# %%
#Neural network training with syntethic in vivo dopamine and serotonin signals. 
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from tensorflow import keras
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
X_filenames1 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/03.09.21 MPTP-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames1= [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/03.09.21 MPTP-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames2 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/03.10.21 MPTP-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames2 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/03.10.21 MPTP-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames3 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/03.26.21 MPTP-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames3 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/03.26.21 MPTP-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames4 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/04.19.21 MPTP-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames4 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/04.19.21 MPTP-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames5 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/04.20.21 MPTP-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames5 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/04.20.21 MPTP-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames6 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/05.13.21 Saline-Saline/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames6 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/05.13.21 Saline-Saline/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames7 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/05.14.21 Saline-Saline/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames7 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/05.14.21 Saline-Saline/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames8 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/05.18.21 Saline-Saline/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames8 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/05.18.21 Saline-Saline/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames9 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/06.10.21 Saline-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames9 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/06.10.21 Saline-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames10 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/010621 Saline-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames10 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/010621 Saline-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames11 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/011121 Saline-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames11 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/011121 Saline-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames12 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/022621 Saline-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames12 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/022621 Saline-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]
X_filenames13 =[r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/First Saline-LD/synthetic_colorplots'+str(i)+'.npz' for i in range(0,100)]
y_filenames13 = [r'C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/Neural Networks Analysis/Fill Color plot NN Undersampled OneMouse/First Saline-LD/array_of_ratios'+str(i)+'.npz' for i in range (0,100)]

#Shuffling filenames upon importing.
X_filenames_shuffled, y_filenames_shuffled = shuffle([X_filenames1,X_filenames2,X_filenames3,X_filenames4,X_filenames5,
X_filenames6,X_filenames7,X_filenames8, X_filenames9, X_filenames10, X_filenames11, X_filenames12, X_filenames13],
[y_filenames1,y_filenames2,y_filenames3,y_filenames4,y_filenames5,y_filenames6,y_filenames7,y_filenames8,y_filenames9,
y_filenames10,y_filenames11,y_filenames12,y_filenames13])

# Used this line as our filename array is not a numpy array.
X_filenames_shuffled = np.array(X_filenames_shuffled)
y_filenames_shuffled = np.array(y_filenames_shuffled)
X_filenames_shuffled= np.ndarray.flatten(X_filenames_shuffled)
y_filenames_shuffled = np.ndarray.flatten(y_filenames_shuffled)
#Divide into train and test: 
X_filenames, X_test_filenames, y_filenames, y_test_filenames = train_test_split(
    X_filenames_shuffled, y_filenames_shuffled, test_size=0.2, random_state=1)
#Divide into train and validation. 
X_train_filenames, X_val_filenames, y_train_filenames, y_val_filenames = train_test_split(
    X_filenames, y_filenames, test_size=0.2, random_state=1)

# %%
class my_custom_generator(keras.utils.Sequence):
  
    def __init__(self, filenames, labels):
        self.filenames = filenames
        self.labels = labels
    
    def __len__(self):
        return len(self.filenames)
  
  
    def __getitem__(self, idx) :
        batch_x = self.filenames[idx]
        array_x = np.load(batch_x)['a'].reshape(29, 275, 300, 1)
        batch_y = self.labels[idx]
        array_y = np.load(batch_y)['a']
        return array_x, array_y

my_training_batch_generator = my_custom_generator(X_train_filenames, y_train_filenames)
my_validation_batch_generator = my_custom_generator(X_val_filenames, y_val_filenames)

# %%
#Define the model. This is only an example and we will need some hyperparametrization. 

def build_and_compile_model(): 
    model = models.Sequential()
    model.add(layers.Conv2D(275, (3, 3), activation='selu',input_shape=(275, 300,1)))
    model.add(layers.MaxPooling2D((3, 3)))
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Conv2D(100, (3, 3), activation='selu'))
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Flatten())
    model.add(layers.Dense(100, activation='relu',kernel_initializer='variance_scaling'))
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dense(100, activation='relu',kernel_initializer='variance_scaling'))
    model.add(layers.LeakyReLU(alpha=0.1))
    model.add(layers.Dense(1))
    model.summary()
    model.compile(loss='mean_absolute_error', optimizer=tf.keras.optimizers.Adam(0.0001), metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model
model = build_and_compile_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 273, 298, 275)     2750
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 91, 99, 275)       0
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 91, 99, 275)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 89, 97, 100)       247600
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 89, 97, 100)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 863300)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               86330100
# ...

# %%
model.fit(my_training_batch_generator,
                steps_per_epoch = 4,
                  epochs = 500,
                  verbose = 1,
                 validation_data = my_validation_batch_generator,
                   validation_steps = 5)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 53s 14s/step - loss: 1.7895 - root_mean_squared_error: 2.2783 - val_loss: 0.3091 - val_root_mean_squared_error: 0.3782
# Epoch 2/500
# 4/4 [==============================] - 50s 14s/step - loss: 0.2073 - root_mean_squared_error: 0.2611 - val_loss: 0.4540 - val_root_mean_squared_error: 0.5251
# Epoch 3/500
# 4/4 [==============================] - 51s 14s/step - loss: 0.2504 - root_mean_squared_error: 0.3055 - val_loss: 0.1852 - val_root_mean_squared_error: 0.2319
# Epoch 4/500
# 4/4 [==============================] - 51s 14s/step - loss: 0.1355 - root_mean_squared_error: 0.1689 - val_loss: 0.1365 - val_root_mean_squared_error: 0.1677
# Epoch 5/500
# 4/4 [==============================] - 54s 14s/step - loss: 0.1772 - root_mean_squared_error: 0.2441 - val_loss: 0.0983 - val_root_mean_squared_error: 0.1371
# Epoch 6/500
# ...

# %%
X_test_filenames=np.load('X_test_filenames.npz')['a']
y_test_filenames=np.load('y_test_filenames.npz')['a']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-945b58438ce7> in <module>
# ----> 1 X_test_filenames=np.load('X_test_filenames.npz')['a']
#       2 y_test_filenames=np.load('y_test_filenames.npz')['a']
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X_test_filenames.npz'

# %%
model = tf.keras.models.load_model('model.test')

# %%
y_predicted=[]
for i in X_test_filenames: 
    x=np.load(i.replace('C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/','C:/Users/chouk/OneDrive - Imperial College London/L-DOPA Analysis/'))['a']
    prediction=model.predict(x.reshape(29, 275, 300, 1))
    y_predicted.append(prediction)

# %%
y_true=[]
for i in y_test_filenames: 
    y_true.append(np.load(i.replace('C:/Users/sergi/OneDrive - Imperial College London/Files/Code Files/L-DOPA Analysis/','C:/Users/chouk/OneDrive - Imperial College London/L-DOPA Analysis/'))['a'])

# %%
from sklearn.metrics import mean_squared_error
#rmse=[mean_squared_error(y_predicted[i], y_true[i]) for i in range(0,len(y_true))]
means_predict= [np.mean(y_predicted[i]) for i in range(0,len(y_predicted))]
means_true =  [np.mean(y_true[i]) for i in range(0,len(y_true))]

# %%
plt.errorbar(y_predicted,y_true,xerr=rmse, fmt='-', color='black', ecolor='tab:blue', elinewidth=3)
plt.xlabel("Predicted ", fontsize = 18)
plt.ylabel("True", fontsize = 18)
#plt.plot(y_predicted, y_true, 'black', linestyle='dashed', alpha=0.5)
# Out:
# Text(0, 0.5, 'True')

# %%
import seaborn as sns
sns.residplot(x=means_predict, y=means_true, lowess=True, color="g")
